# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DS_kaggle_edited_v2/Bangkok/Test/3H_temperature_Bangkok.csv")
df.head()
# Out:
#               datetime  Temp(C)     lat      long
# 0  2019-03-18 01:00:00     29.2  13.754  100.5014
# 1  2019-03-18 04:00:00     28.7  13.754  100.5014
# 2  2019-03-18 07:00:00     29.3  13.754  100.5014
# 3  2019-03-18 10:00:00     33.4  13.754  100.5014
# 4  2019-03-18 13:00:00     34.5  13.754  100.5014

# %%
pm = pd.read_csv(
    "DS_kaggle_edited_v2/Bangkok/Train/Bangkok.txt",
    comment="%",
    sep="\t",
    header=None,
    names=["year", "month", "day", "hour", "pm25", "pm10_mask", "retrospective"]
)
pm.head()
# Out:
#    year  month  day  hour  pm25  pm10_mask  retrospective
# 0  2016      3    3     8  62.9        1.0              0
# 1  2016      3    3     9  62.9        1.0              0
# 2  2016      3    3    10  55.5        1.0              0
# 3  2016      3    3    11  55.5        1.0              0
# 4  2016      3    3    12  47.9        1.0              0

# %%
pm["datetime"] = pd.to_datetime(pm[["year","month","day","hour"]])
pm = pm.sort_values("datetime")
pm.head()
# Out:
#    year  month  day  hour  pm25  pm10_mask  retrospective            datetime
# 0  2016      3    3     8  62.9        1.0              0 2016-03-03 08:00:00
# 1  2016      3    3     9  62.9        1.0              0 2016-03-03 09:00:00
# 2  2016      3    3    10  55.5        1.0              0 2016-03-03 10:00:00
# 3  2016      3    3    11  55.5        1.0              0 2016-03-03 11:00:00
# 4  2016      3    3    12  47.9        1.0              0 2016-03-03 12:00:00

# %%
temp = pd.read_csv(
    "DS_kaggle_edited_v2/Bangkok/Train/3H_temperature_Bangkok.csv"
)
wind = pd.read_csv(
    "DS_kaggle_edited_v2/Bangkok/Train/3H_wind_Bangkok.csv"
)

temp.head()
# Out:
#               datetime  Temp(C)     lat      long
# 0  2016-03-03 01:00:00     25.5  13.754  100.5014
# 1  2016-03-03 04:00:00     25.0  13.754  100.5014
# 2  2016-03-03 07:00:00     26.4  13.754  100.5014
# 3  2016-03-03 10:00:00     31.4  13.754  100.5014
# 4  2016-03-03 13:00:00     34.1  13.754  100.5014

# %%
temp["datetime"] = pd.to_datetime(temp["datetime"])
wind["datetime"] = pd.to_datetime(wind["datetime"])

df = pm.merge(temp[["datetime","Temp(C)"]], on="datetime", how="left")
df = df.merge(wind[["datetime","Wind(m/s)"]], on="datetime", how="left")

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 5
#       2 wind["datetime"] = pd.to_datetime(wind["datetime"])
#       4 df = pm.merge(temp[["datetime","Temp(C)"]], on="datetime", how="left")
# ----> 5 df = df.merge(wind[["datetime","Wind(m/s)"]], on="datetime", how="left")
#       7 df.head()
#
# File d:\final_module8\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File d:\final_module8\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File d:\final_module8\.venv\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Wind(m/s)'] not in index"
